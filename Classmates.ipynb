# %%
import pandas as pd

# %%
#load the data
df_CS = pd.read_csv('./CSSE386-OL1.csv',skiprows=3)

# %%
df.head(3)
# Out:
#    Username        Last  First Middle  Banner ID Major Class Year   Advisor  \
# 0   albalod  Alba-Lopez  David    NaN  801510488    CS    SR   Y4  anderson
# 1    chenm6        Chen   Mory    NaN  801517061    CS    SR   Y4   stouder
# 2  dunawasg     Dunaway    Sam      G  801481205    CS    SR   Y4  anderson
#
#                       Email Campus Mail
# 0   ALBALOD@rose-hulman.edu      CM 804
# 1    CHENM6@rose-hulman.edu      CM 877
# 2  DUNAWASG@rose-hulman.edu      CM 922

# %%
df.shape
# Out:
# (27, 11)

# %%
df.tail(3)
# Out:
#     Username   Last   First Middle  Banner ID    Major Class Year   Advisor  \
# 24      xus2     Xu   Siwei    NaN  801521207    ME/CS    SR   Y4     purdy
# 25  zhangy16  Zhang  Yinzhe    NaN  801457740  CS/ECON    SR   Y5  chenowet
# 26     zhuy9    Zhu  Darren    NaN  801608114       CS    SR   Y3    yoder1
#
#                        Email Campus Mail
# 24      XUS2@rose-hulman.edu     CM 1338
# 25  ZHANGY16@rose-hulman.edu     CM 2158
# 26     ZHUY9@rose-hulman.edu      CM 616

# %%
df.index
# Out:
# RangeIndex(start=0, stop=27, step=1)

# %%
df.columns #attibutes
# Out:
# Index(['Username', 'Last', 'First', 'Middle', 'Banner ID', 'Major', 'Class',
#        'Year', 'Advisor', 'Email', 'Campus Mail'],
#       dtype='object')

# %%
df.values #actual value in the data
# Out:
# array([['albalod', 'Alba-Lopez', 'David', nan, 801510488, 'CS', 'SR',
#         'Y4', 'anderson', 'ALBALOD@rose-hulman.edu', 'CM 804'],
#        ['chenm6', 'Chen', 'Mory', nan, 801517061, 'CS', 'SR', 'Y4',
#         'stouder', 'CHENM6@rose-hulman.edu', 'CM 877'],
#        ['dunawasg', 'Dunaway', 'Sam', 'G', 801481205, 'CS', 'SR', 'Y4',
#         'anderson', 'DUNAWASG@rose-hulman.edu', 'CM 922'],
#        ['fengr', 'Feng', 'Steven', nan, 801600121, 'MA', 'SR', 'Y3',
#         'holder', 'FENGR@rose-hulman.edu', 'CM 216'],
#        ['flickisc', 'Flickinger', 'Samuel', 'C', 801538468, 'CS', 'SR',
#         'Y4', 'anderson', 'FLICKISC@rose-hulman.edu', 'CM 948'],
#        ['glaveaf', 'Glave', 'Aaron', 'F', 801512468, 'MA/CS', 'SR', 'Y4',
#         'mcsweene', 'GLAVEAF@rose-hulman.edu', 'CM 975'],
#        ['harnesrs', 'Harness', 'Rachel', 'S', 801525294, 'CS', 'JR',
#         'Y4', 'mohan', 'HARNESRS@rose-hulman.edu', 'CM 997'],
# ...

# %%
df.Middle #NaN: not a number -> they dont have middle name(missing values)
# Out:
# 0     NaN
# 1     NaN
# 2       G
# 3     NaN
# 4       C
# 5       F
# 6       S
# 7     NaN
# 8     NaN
# 9       A
# 10      S
# 11    NaN
# 12      S
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17      L
# 18      S
# 19      G
# 20      A
# 21    NaN
# 22      R
# 23      T
# 24    NaN
# 25    NaN
# 26    NaN
# Name: Middle, dtype: object

# %%
#load the data
df_MA = pd.read_csv('./MA384-OL1.csv',skiprows=3)
df_MA.head(3)
# Out:
#    Username     Last     First Middle  Banner ID Major Class Year   Advisor  \
# 0     alima      Ali  Mohammed      A  801514073    SE    JR   Y4  anderson
# 1  ballartj  Ballard      T.J.      J  801513243   CPE    SR   Y4   miller4
# 2   chenx16     Chen     Doris    NaN  801622394    CS    SR   Y3  wollowsk
#
#                       Email Campus Mail
# 0     ALIMA@rose-hulman.edu      CM 806
# 1  BALLARTJ@rose-hulman.edu      CM 826
# 2   CHENX16@rose-hulman.edu     CM 3105

# %%
df = pd.concat([df_MA,df_CS]) #combine them together
df.head(3)
# Out:
#    Username     Last     First Middle  Banner ID Major Class Year   Advisor  \
# 0     alima      Ali  Mohammed      A  801514073    SE    JR   Y4  anderson
# 1  ballartj  Ballard      T.J.      J  801513243   CPE    SR   Y4   miller4
# 2   chenx16     Chen     Doris    NaN  801622394    CS    SR   Y3  wollowsk
#
#                       Email Campus Mail
# 0     ALIMA@rose-hulman.edu      CM 806
# 1  BALLARTJ@rose-hulman.edu      CM 826
# 2   CHENX16@rose-hulman.edu     CM 3105

# %%
df.shape
# Out:
# (53, 11)

# %%
df['Major'].head(3)
# Out:
# 0     SE
# 1    CPE
# 2     CS
# Name: Major, dtype: object

# %%
df.Major.value_counts() #count their values
# Out:
# CS         26
# CPE         6
# MA          4
# CS/DATA     3
# SE          3
# ME          2
# ME/CS       2
# CS/SE       1
# CS/MA       1
# MA/DATA     1
# MA/CS       1
# CPE/CS      1
# CS/ECON     1
# ME/MA       1
# Name: Major, dtype: int64

# %%
df[df.Major=='CS']
# Out:
#     Username        Last      First Middle  Banner ID Major Class Year  \
# 2    chenx16        Chen      Doris    NaN  801622394    CS    SR   Y3
# 6      cuiy1         Cui  Augustine    NaN  801522590    CS    SR   Y4
# 9   grayledw    Grayless      Derek      W  801526809    CS    SR   Y4
# 14     linj3         Lin     Jiafan    NaN  801623455    CS    SR   Y3
# 17   myersjm       Myers    Jessica      M  801502219    CS    SR   Y4
# 18   ouyangr      Ouyang     Aurora    NaN  801539537    CS    SR   Y4
# 19  schluncg    Schlundt      Caleb      G  801527041    CS    SR   Y4
# 20   slaughb   Slaughter    Brionna      A  801481232    CS    SR   Y4
# 24    yangz4        Yang       Zhen    NaN  801619031    CS    JR   Y3
# 0    albalod  Alba-Lopez      David    NaN  801510488    CS    SR   Y4
# 1     chenm6        Chen       Mory    NaN  801517061    CS    SR   Y4
# 2   dunawasg     Dunaway        Sam      G  801481205    CS    SR   Y4
# ...
